# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('NREGA.csv')
data.head()
# Out:
#    SNo.           state_name             district_name  \
# 0     1  ANDAMAN AND NICOBAR                  NICOBARS
# 1     2  ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN
# 2     3  ANDAMAN AND NICOBAR             SOUTH ANDAMAN
# 3     4       ANDHRA PRADESH                SRIKAKULAM
# 4     5       ANDHRA PRADESH              VIZIANAGARAM
#
#    Total No. of JobCards issued  Total No. of Workers  \
# 0                          6173                  9866
# 1                         18521                 29500
# 2                         13726                 17491
# 3                        445787                743762
# 4                        388651                694622
#
#    Total No. of Active Job Cards  Total No. of Active Workers  \
# 0                           1007                         2011
# 1                           6477                        11920
# 2                           3420                         5016
# ...

# %%
data.dtypes
# Out:
# SNo.                                                            int64
# state_name                                                     object
# district_name                                                  object
# Total No. of JobCards issued                                    int64
# Total No. of Workers                                            int64
# Total No. of Active Job Cards                                   int64
# Total No. of Active Workers                                     int64
# SC workers against active workers                               int64
# ST workers against active workers                               int64
# Approved Labour Budget                                          int64
# Persondays of Central Liability so far                          int64
# SC persondays                                                   int64
# ST persondays                                                   int64
# ...

# %%
data.isna().sum()
# Out:
# SNo.                                                          0
# state_name                                                    0
# district_name                                                 0
# Total No. of JobCards issued                                  0
# Total No. of Workers                                          0
# Total No. of Active Job Cards                                 0
# Total No. of Active Workers                                   0
# SC workers against active workers                             0
# ST workers against active workers                             0
# Approved Labour Budget                                        0
# Persondays of Central Liability so far                        0
# SC persondays                                                 0
# ST persondays                                                 0
# Women Persondays                                              0
# Average days of employment provided per Household             0
# ...

# %%
for i in data.select_dtypes(include=['number']).columns:
  print(i)
  has_negatives = (data[i] < 0).any()
  print(has_negatives)
# Out:
# SNo.
# False
# Total No. of JobCards issued
# False
# Total No. of Workers
# False
# Total No. of Active Job Cards
# False
# Total No. of Active Workers
# False
# SC workers against active workers
# False
# ST workers against active workers
# False
# Approved Labour Budget
# False
# Persondays of Central Liability so far
# False
# SC persondays
# False
# ST persondays
# False
# Women Persondays
# False
# Average days of employment provided per Household
# False
# Average Wage rate per day per person(Rs.)
# False
# Total No of HHs completed 100 Days of Wage Employment
# False
# Total Households Worked
# False
# Total Individuals Worked
# False
# Differently abled persons worked
# False
# Number of GPs with NIL exp
# False
# Total No. of Works Takenup (New+Spill Over)
# False
# Number of Ongoing Works
# False
# Number of Completed Works
# False
# % of NRM Expenditure(Public + Individual)
# False
# % of Category B Works
# False
# ...

# %%
data.describe()
# Out:
#              SNo.  Total No. of JobCards issued  Total No. of Workers  \
# count  740.000000                  7.400000e+02          7.400000e+02
# mean   370.500000                  2.104687e+05          3.638288e+05
# std    213.763888                  1.823353e+05          3.233418e+05
# min      1.000000                  2.682000e+03          2.790000e+03
# 25%    185.750000                  8.367925e+04          1.418820e+05
# 50%    370.500000                  1.670905e+05          2.898630e+05
# 75%    555.250000                  2.837125e+05          4.951898e+05
# max    740.000000                  1.404131e+06          2.362498e+06
#
#        Total No. of Active Job Cards  Total No. of Active Workers  \
# count                     740.000000                 7.400000e+02
# mean                   131146.417568                 2.371340e+05
# std                    114671.685185                 2.154017e+05
# min                         1.000000                 2.000000e+00
# ...

# %%
#1.Worker Demographics:

# %% [markdown]
# ## DATA PREPARATION

# %%
data_wd=data[['state_name','district_name','Total No. of Active Workers','SC workers against active workers','ST workers against active workers']]
data_wd.head(10)
# Out:
#             state_name             district_name  Total No. of Active Workers  \
# 0  ANDAMAN AND NICOBAR                  NICOBARS                         2011
# 1  ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN                        11920
# 2  ANDAMAN AND NICOBAR             SOUTH ANDAMAN                         5016
# 3       ANDHRA PRADESH                SRIKAKULAM                       680409
# 4       ANDHRA PRADESH              VIZIANAGARAM                       648430
# 5       ANDHRA PRADESH            VISAKHAPATANAM                        51975
# 6       ANDHRA PRADESH             EAST GODAVARI                       202387
# 7       ANDHRA PRADESH             WEST GODAVARI                       218198
# 8       ANDHRA PRADESH                   KRISHNA                       317990
# 9       ANDHRA PRADESH                    GUNTUR                       150682
#
#    SC workers against active workers  ST workers against active workers
# ...

# %%
for i in data_wd.select_dtypes(include=['number']).columns:
  sns.displot(data_wd[i])

# %%
for i in data_wd.select_dtypes(include=['number']).columns:
  sns.boxplot(x=data_wd[i])
  plt.show()

# %%
data_wd.dtypes
# Out:
# state_name                           object
# district_name                        object
# Total No. of Active Workers           int64
# SC workers against active workers     int64
# ST workers against active workers     int64
# dtype: object

# %%
data_wd['ST workers against active workers'] = np.sqrt(data_wd['ST workers against active workers'])
# Out:
# <ipython-input-12-8114bbea0771>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_wd['ST workers against active workers'] = np.sqrt(data_wd['ST workers against active workers'])

# %%
# Assuming 'column_name' is the skewed column
data_wd['SC workers against active workers'] = np.sqrt(data_wd['SC workers against active workers'])
# Out:
# <ipython-input-13-b905ddd2dff9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_wd['SC workers against active workers'] = np.sqrt(data_wd['SC workers against active workers'])

# %%
# Assuming 'column_name' is the skewed column
data_wd['Total No. of Active Workers'] = np.sqrt(data_wd['Total No. of Active Workers'])
# Out:
# <ipython-input-14-866abd31a3cb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_wd['Total No. of Active Workers'] = np.sqrt(data_wd['Total No. of Active Workers'])

# %%
data_wd = data_wd.replace(0, data_wd.median())
# Out:
# <ipython-input-15-a864e458484f>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_wd = data_wd.replace(0, data_wd.median())

# %%
data_wd.head(10)
# Out:
#             state_name             district_name  Total No. of Active Workers  \
# 0  ANDAMAN AND NICOBAR                  NICOBARS                    44.844175
# 1  ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN                   109.178753
# 2  ANDAMAN AND NICOBAR             SOUTH ANDAMAN                    70.823725
# 3       ANDHRA PRADESH                SRIKAKULAM                   824.869081
# 4       ANDHRA PRADESH              VIZIANAGARAM                   805.251514
# 5       ANDHRA PRADESH            VISAKHAPATANAM                   227.980262
# 6       ANDHRA PRADESH             EAST GODAVARI                   449.874427
# 7       ANDHRA PRADESH             WEST GODAVARI                   467.116688
# 8       ANDHRA PRADESH                   KRISHNA                   563.906021
# 9       ANDHRA PRADESH                    GUNTUR                   388.177794
#
#    SC workers against active workers  ST workers against active workers
# ...

# %%
for i in data_wd.select_dtypes(include=['number']).columns:
  sns.displot(data_wd[i])

# %%
import pandas as pd

for i in data_wd.select_dtypes(include=['number']).columns:
# Assuming 'data_wd' is your DataFrame and 'column_name' is the specific column
  column = data_wd[i]

  Q1 = column.quantile(0.25)
  Q3 = column.quantile(0.75)
  IQR = Q3 - Q1

# Finding the number of outliers
# Define the boundaries for outliers
  lower_bound = Q1 - 1.5 * IQR
  upper_bound = Q3 + 1.5 * IQR

# Filter the DataFrame to exclude outliers in the specified column
  data_wd = data_wd[(column >= lower_bound) & (column <= upper_bound)]

# %%
for i in data_wd.select_dtypes(include=['number']).columns:
  sns.boxplot(x=data_wd[i])
  plt.show()

# %%
data_wd.head(10)
# Out:
#             state_name             district_name  Total No. of Active Workers  \
# 0  ANDAMAN AND NICOBAR                  NICOBARS                    44.844175
# 1  ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN                   109.178753
# 2  ANDAMAN AND NICOBAR             SOUTH ANDAMAN                    70.823725
# 3       ANDHRA PRADESH                SRIKAKULAM                   824.869081
# 4       ANDHRA PRADESH              VIZIANAGARAM                   805.251514
# 5       ANDHRA PRADESH            VISAKHAPATANAM                   227.980262
# 6       ANDHRA PRADESH             EAST GODAVARI                   449.874427
# 7       ANDHRA PRADESH             WEST GODAVARI                   467.116688
# 8       ANDHRA PRADESH                   KRISHNA                   563.906021
# 9       ANDHRA PRADESH                    GUNTUR                   388.177794
#
#    SC workers against active workers  ST workers against active workers
# ...

# %%
for i in data_wd.select_dtypes(include=['number']).columns:
  data_wd[i]=data_wd[i].astype(int)
data_wd.head(6)
# Out:
#             state_name             district_name  Total No. of Active Workers  \
# 0  ANDAMAN AND NICOBAR                  NICOBARS                           44
# 1  ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN                          109
# 2  ANDAMAN AND NICOBAR             SOUTH ANDAMAN                           70
# 3       ANDHRA PRADESH                SRIKAKULAM                          824
# 4       ANDHRA PRADESH              VIZIANAGARAM                          805
# 5       ANDHRA PRADESH            VISAKHAPATANAM                          227
#
#    SC workers against active workers  ST workers against active workers
# 0                                176                                 40
# 1                                176                                108
# 2                                176                                108
# 3                                249                                199
# ...

# %% [markdown]
# ## DATA EXPLORATION

# %%
plt.figure(figsize=(8, 6))
corrlon=data_wd.corr()
heatmap = sns.heatmap(corrlon, annot=True, cmap="coolwarm", fmt=".3f")
plt.title('Correlation Heatmap')
plt.show()
# Out:
# <ipython-input-22-1635172e13fe>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrlon=data_wd.corr()

# %%
data_wd['SC Worker Proportion']=data_wd['SC workers against active workers'] / data_wd['Total No. of Active Workers']
data_wd['ST Worker Proportion']=data_wd['ST workers against active workers'] / data_wd['Total No. of Active Workers']

# %%
data_wd.head(10)
# Out:
#             state_name             district_name  Total No. of Active Workers  \
# 0  ANDAMAN AND NICOBAR                  NICOBARS                           44
# 1  ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN                          109
# 2  ANDAMAN AND NICOBAR             SOUTH ANDAMAN                           70
# 3       ANDHRA PRADESH                SRIKAKULAM                          824
# 4       ANDHRA PRADESH              VIZIANAGARAM                          805
# 5       ANDHRA PRADESH            VISAKHAPATANAM                          227
# 6       ANDHRA PRADESH             EAST GODAVARI                          449
# 7       ANDHRA PRADESH             WEST GODAVARI                          467
# 8       ANDHRA PRADESH                   KRISHNA                          563
# 9       ANDHRA PRADESH                    GUNTUR                          388
#
#    SC workers against active workers  ST workers against active workers  \
# ...

# %%
data_wd['Total SC/ST'] = (data_wd['SC workers against active workers'] + data_wd['ST workers against active workers'])

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Calculating sizes based on proportions
sizes = [data_wd['SC Worker Proportion'].mean(), data_wd['ST Worker Proportion'].mean()]  # Example using mean values

# Labels for the pie chart
labels = ['SC Workers', 'ST Workers']

# Plotting the pie chart
plt.figure(figsize=(8, 6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Proportions of SC and ST Workers in Active Workforce')
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular

# Display the pie chart
plt.show()

# %% [markdown]
# From the pie chart,We can understand that SC workers are more in number than ST workers in the active workforce.

# %%
# Grouping data by state and summing SC and ST workers employed
state_workers = data_wd.groupby('state_name')[['SC workers against active workers', 'ST workers against active workers']].sum()

# Plotting a stacked bar graph for SC and ST workers employed in different states
state_workers.plot(kind='bar', stacked=True, figsize=(12, 8))
plt.title('Number of SC and ST Workers Employed in Different States')
plt.xlabel('States')
plt.ylabel('Number of Workers')
plt.legend(["SC Workers", "ST Workers"])
plt.xticks(rotation=90)
plt.show()


# Finding the top 5 states that have employed the most SC and ST workers
state_workers['Total SC ST Workers'] = state_workers['SC workers against active workers'] + state_workers['ST workers against active workers']
top_5_states = state_workers.nlargest(5, 'Total SC ST Workers')
print("Top 5 states with most SC/ST workers employed:")
print(top_5_states)

# %% [markdown]
# From the above histogram,we can observe that Uttar Pradesh has large number of active SC/ST workers when compared to the other states .
#
# This means that Uttar Pradesh is employing more number of people belonging to SC/ST class according to the MNREGA Act,2005.

# %%
# Finding the bottom 5 states that have employed the least SC and ST workers
bottom_5_states = state_workers.nsmallest(5, 'Total SC ST Workers')
print("Bottom 5 states with least SC/ST workers employed:")
print(bottom_5_states)
# Out:
# Top 5 states with most SC/ST workers employed:
#                 SC workers against active workers  \
# state_name
# UTTAR PRADESH                               17882
# MADHYA PRADESH                               8479
# RAJASTHAN                                    7696
# CHHATTISGARH                                 4483
# TELANGANA                                    7054
#
#                 ST workers against active workers  Total SC ST Workers
# state_name
# UTTAR PRADESH                                2233                20115
# MADHYA PRADESH                               9646                18125
# RAJASTHAN                                    5434                13130
# CHHATTISGARH                                 8527                13010
# TELANGANA                                    5906                12960
# Bottom 5 states with least SC/ST workers employed:
#                   SC workers against active workers  \
# state_name
# ...

# %% [markdown]
# From the above histogram,we can observe that Goa has small number of active SC/ST workers when compared to the other states .
#
# This means that Goa is employing less number of people belonging to SC/ST class according to the MNREGA Act,2005.

# %%
# Assuming the dataset is named data_wd

# Calculate the ratio of SC/ST workers against total workers for each state
data_wd['SC/ST Ratio'] = (data_wd['SC workers against active workers'] + data_wd['ST workers against active workers']) / data_wd['Total No. of Active Workers']

# Grouping data by state and finding the top 5 states with the highest ratio of SC/ST workers against total workers
state_wise_top_ratios = data_wd.groupby('state_name')['SC/ST Ratio'].max().nlargest(5)
top_5_states = state_wise_top_ratios.reset_index()

print("Top 5 states with the highest SC/ST ratios relative to other categories")
print(top_5_states[['state_name', 'SC/ST Ratio']])
# Out:
# Top 5 states with the highest SC/ST ratios relative to other categories
#             state_name  SC/ST Ratio
# 0     DN HAVELI AND DD   284.000000
# 1        UTTAR PRADESH    15.857143
# 2          LAKSHADWEEP     8.954545
# 3  ANDAMAN AND NICOBAR     4.909091
# 4    ARUNACHAL PRADESH     3.146341

# %% [markdown]
# This means that the active workforce is comprised by a majority of SC/ST workers in the state of  DN HAVELI AND DD in accordance with the MNREGA scheme.

# %%
# Selecting a specific state (change 'YOUR_STATE_NAME' to the desired state)
specific_state = 'UTTAR PRADESH'
state_data = data_wd[data_wd['state_name'] == specific_state]

# Grouping data by district within the specific state and summing SC and ST workers employed
district_workers = state_data.groupby('district_name')[['SC workers against active workers', 'ST workers against active workers']].sum()

# Plotting a stacked bar graph for SC and ST workers employed in different districts of the specific state
district_workers.plot(kind='bar', stacked=True, figsize=(12, 8))
plt.title(f'Number of SC and ST Workers Employed in Different Districts of {specific_state}')
plt.xlabel('Districts')
plt.ylabel('Number of Workers')
plt.legend(["SC Workers", "ST Workers"])
plt.xticks(rotation=90)
plt.show()

# Finding the top 5 districts that have employed the most SC and ST workers
district_workers['Total SC ST Workers'] = district_workers['SC workers against active workers'] + district_workers['ST workers against active workers']
top_5_states = district_workers.nlargest(5, 'Total SC ST Workers')
print("Top 5 states with most SC/ST workers employed:")
print(top_5_states)
# Out:
# Top 5 states with most SC/ST workers employed:
#                SC workers against active workers  \
# district_name
# SONBHADRA                                    337
# KHERI                                        408
# PRAYAGRAJ                                    449
# MIRZAPUR                                     366
# AZAMGARH                                     374
#
#                ST workers against active workers  Total SC ST Workers
# district_name
# SONBHADRA                                    318                  655
# KHERI                                         92                  500
# PRAYAGRAJ                                     18                  467
# MIRZAPUR                                      57                  423
# AZAMGARH                                      30                  404

# %% [markdown]
# From the above histogram,we can observe that Sonbhadra district has large number of active SC/ST workers when compared to the other districts in Uttar Pradesh.
#
# This means that Sonbhadra district is employing more number of people belonging to SC/ST class according to the MNREGA Act,2005 in Uttar Pradesh.

# %%
# Finding the bottom 5 states that have employed the least SC and ST workers
bottom_5_states = district_workers.nsmallest(5, 'Total SC ST Workers')
print("Bottom 5 states with least SC/ST workers employed:")
print(bottom_5_states)
# Out:
# Bottom 5 states with least SC/ST workers employed:
#                      SC workers against active workers  \
# district_name
# GAUTAM BUDDHA NAGAR                                 22
# BAGHPAT                                             49
# SHAMLI                                              66
# HAPUR                                               73
# GHAZIABAD                                            3
#
#                      ST workers against active workers  Total SC ST Workers
# district_name
# GAUTAM BUDDHA NAGAR                                  3                   25
# BAGHPAT                                              3                   52
# SHAMLI                                               6                   72
# HAPUR                                                2                   75
# GHAZIABAD                                          108                  111

# %% [markdown]
# From the above histogram,we can observe that Gautam Buddha Nagar has small number of active SC/ST workers when compared to the other districts in UP .
#
# This means that Gautam Buddha Nagar is employing less number of people belonging to SC/ST class according to the MNREGA Act,2005 in UP.

# %%
# Assuming the dataset is named data_wd
specific_state = 'UTTAR PRADESH'
state_data = data_wd[data_wd['state_name'] == specific_state]

# Calculate the ratio of SC/ST workers against total workers for each state
#data_wd['SC/ST Ratio'] = (data_wd['SC workers against active workers'] + data_wd['ST workers against active workers']) / data_wd['Total No. of Active Workers']

# Grouping data by state and finding the top 5 states with the highest ratio of SC/ST workers against total workers
district_wise_top_ratios = state_data.groupby('district_name')['SC/ST Ratio'].max().nlargest(5)
top_5_states = district_wise_top_ratios.reset_index()

print("Top 5 states with the highest SC/ST ratios relative to other categories")
print(top_5_states[['district_name', 'SC/ST Ratio']])
# Out:
# Top 5 states with the highest SC/ST ratios relative to other categories
#   district_name  SC/ST Ratio
# 0     GHAZIABAD    15.857143
# 1     SONBHADRA     1.088040
# 2       LUCKNOW     0.853868
# 3      LALITPUR     0.754491
# 4  KANPUR NAGAR     0.752351

# %% [markdown]
# This means that the active workforce is comprised by a majority of SC/ST workers in the district of   Ghaziabad in accordance with the MNREGA scheme in UP state.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'data' contains your dataset

# Selecting a specific state (change 'YOUR_STATE_NAME' to the desired state)
specific_state = 'GOA'
state_data = data_wd[data_wd['state_name'] == specific_state]

# Grouping data by district within the specific state and summing SC and ST workers employed
district_workers = state_data.groupby('district_name')[['SC workers against active workers', 'ST workers against active workers']].sum()

# Plotting a stacked bar graph for SC and ST workers employed in different districts of the specific state
district_workers.plot(kind='bar', stacked=True, figsize=(12, 8))
plt.title(f'Number of SC and ST Workers Employed in Different Districts of {specific_state}')
plt.xlabel('Districts')
plt.ylabel('Number of Workers')
plt.legend(["SC Workers", "ST Workers"])
plt.xticks(rotation=90)
plt.show()

# %%
state_workers.head(7)
# Out:
#                      SC workers against active workers  \
# state_name
# ANDAMAN AND NICOBAR                                528
# ANDHRA PRADESH                                    7228
# ARUNACHAL PRADESH                                 2308
# ASSAM                                             3501
# BIHAR                                             7963
# CHHATTISGARH                                      4483
# DN HAVELI AND DD                                   176
#
#                      ST workers against active workers  Total SC ST Workers
# state_name
# ANDAMAN AND NICOBAR                                256                  784
# ANDHRA PRADESH                                    2985                10213
# ARUNACHAL PRADESH                                 3160                 5468
# ASSAM                                             5607                 9108
# BIHAR                                             2239                10202
# ...

# %%
data_wd.head(7)
# Out:
#             state_name             district_name  Total No. of Active Workers  \
# 0  ANDAMAN AND NICOBAR                  NICOBARS                           44
# 1  ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN                          109
# 2  ANDAMAN AND NICOBAR             SOUTH ANDAMAN                           70
# 3       ANDHRA PRADESH                SRIKAKULAM                          824
# 4       ANDHRA PRADESH              VIZIANAGARAM                          805
# 5       ANDHRA PRADESH            VISAKHAPATANAM                          227
# 6       ANDHRA PRADESH             EAST GODAVARI                          449
#
#    SC workers against active workers  ST workers against active workers  \
# 0                                176                                 40
# 1                                176                                108
# 2                                176                                108
# ...

# %%
#2.Budget Analysis:

# %% [markdown]
# ## DATA PREPARATION

# %%
data_bg=data[['state_name','district_name','Approved Labour Budget','Total Exp(Rs. in Lakhs.)']]
data_bg.head(11)
# Out:
#              state_name             district_name  Approved Labour Budget  \
# 0   ANDAMAN AND NICOBAR                  NICOBARS                   34000
# 1   ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN                   76000
# 2   ANDAMAN AND NICOBAR             SOUTH ANDAMAN                   40000
# 3        ANDHRA PRADESH                SRIKAKULAM                16700000
# 4        ANDHRA PRADESH              VIZIANAGARAM                16800000
# 5        ANDHRA PRADESH            VISAKHAPATANAM                 1400000
# 6        ANDHRA PRADESH             EAST GODAVARI                 4800000
# 7        ANDHRA PRADESH             WEST GODAVARI                 3400000
# 8        ANDHRA PRADESH                   KRISHNA                 6900000
# 9        ANDHRA PRADESH                    GUNTUR                 2900000
# 10       ANDHRA PRADESH                  PRAKASAM                15000000
#
#     Total Exp(Rs. in Lakhs.)
# 0                   5.470080
# ...

# %%
data_bg.isna().sum()
# Out:
# state_name                  0
# district_name               0
# Approved Labour Budget      0
# Total Exp(Rs. in Lakhs.)    0
# dtype: int64

# %%
for i in data_bg.select_dtypes(include=['number']).columns:
  print(i)
  has_negatives = (data_bg[i] < 0).any()
  print(has_negatives)
# Out:
# Approved Labour Budget
# False
# Total Exp(Rs. in Lakhs.)
# False

# %%
plt.figure(figsize=(8, 6))
corrlon=data_bg.corr()
heatmap = sns.heatmap(corrlon, annot=True, cmap="coolwarm", fmt=".3f")
plt.title('Correlation Heatmap')
plt.show()
# Out:
# <ipython-input-40-4eedf8df6966>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrlon=data_bg.corr()

# %%
for i in data_bg.select_dtypes(include=['number']).columns:
  sns.displot(data_bg[i])

# %%
for i in data_bg.select_dtypes(include=['number']).columns:
  sns.boxplot(x=data_bg[i])
  plt.show()

# %%
"""data_bg.loc[:, 'Approved Labour Budget'] = np.sqrt(data_bg['Approved Labour Budget'])
data_bg.loc[:, 'Total Exp(Rs. in Lakhs.)'] = np.sqrt(data_bg['Total Exp(Rs. in Lakhs.)'])"""
# Out:
# "data_bg.loc[:, 'Approved Labour Budget'] = np.sqrt(data_bg['Approved Labour Budget'])\ndata_bg.loc[:, 'Total Exp(Rs. in Lakhs.)'] = np.sqrt(data_bg['Total Exp(Rs. in Lakhs.)'])"

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Assuming 'df' is your DataFrame with the columns: 'Approved Labour Budget' and 'Total Exp(Rs. in Lakhs.)'

# Subset the columns containing integer features
integer_columns = ['Approved Labour Budget', 'Total Exp(Rs. in Lakhs.)']

# Initialize MinMaxScaler
scaler = MinMaxScaler()

# Normalize the integer columns using Min-Max scaling
data_bg[integer_columns] = scaler.fit_transform(data_bg[integer_columns])
# Out:
# <ipython-input-44-d5a1eb77d29d>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_bg[integer_columns] = scaler.fit_transform(data_bg[integer_columns])

# %%
data_bg.loc[:, 'Approved Labour Budget'] = np.sqrt(data_bg['Approved Labour Budget'])
data_bg.loc[:, 'Total Exp(Rs. in Lakhs.)'] = np.sqrt(data_bg['Total Exp(Rs. in Lakhs.)'])
# Out:
# <ipython-input-45-09e61995bfc4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_bg.loc[:, 'Approved Labour Budget'] = np.sqrt(data_bg['Approved Labour Budget'])
# <ipython-input-45-09e61995bfc4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_bg.loc[:, 'Total Exp(Rs. in Lakhs.)'] = np.sqrt(data_bg['Total Exp(Rs. in Lakhs.)'])

# %%
import pandas as pd

for i in data_bg.select_dtypes(include=['number']).columns:
# Assuming 'data_bg' is your DataFrame and 'column_name' is the specific column
  column = data_bg[i]

  Q1 = column.quantile(0.25)
  Q3 = column.quantile(0.75)
  IQR = Q3 - Q1

# Finding the number of outliers
# Define the boundaries for outliers
  lower_bound = Q1 - 1.5 * IQR
  upper_bound = Q3 + 1.5 * IQR

# Filter the DataFrame to exclude outliers in the specified column
  data_bg = data_bg[(column >= lower_bound) & (column <= upper_bound)]

# %%
for i in data_bg.select_dtypes(include=['number']).columns:
  sns.boxplot(x=data_bg[i])
  plt.show()

# %%
for i in data_bg.select_dtypes(include=['number']).columns:
  sns.displot(data_bg[i])

# %% [markdown]
# ## DATA EXPLORATION

# %%
data_bg.head(10)
# Out:
#              state_name             district_name  Approved Labour Budget  \
# 0   ANDAMAN AND NICOBAR                  NICOBARS                0.040699
# 1   ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN                0.060849
# 2   ANDAMAN AND NICOBAR             SOUTH ANDAMAN                0.044145
# 5        ANDHRA PRADESH            VISAKHAPATANAM                0.261163
# 6        ANDHRA PRADESH             EAST GODAVARI                0.483579
# 7        ANDHRA PRADESH             WEST GODAVARI                0.406993
# 8        ANDHRA PRADESH                   KRISHNA                0.579791
# 9        ANDHRA PRADESH                    GUNTUR                0.375877
# 12       ANDHRA PRADESH                  CHITTOOR                0.583977
# 13       ANDHRA PRADESH                     Y.S.R                0.588134
#
#     Total Exp(Rs. in Lakhs.)
# 0                   0.010387
# 1                   0.057556
# 2                   0.039522
# 5                   0.282047
# ...

# %%
data_bg.describe()
# Out:
#        Approved Labour Budget  Total Exp(Rs. in Lakhs.)
# count              721.000000                721.000000
# mean                 0.329075                  0.319861
# std                  0.156080                  0.168892
# min                  0.000000                  0.000000
# 25%                  0.220561                  0.192043
# 50%                  0.330079                  0.313342
# 75%                  0.426058                  0.426048
# max                  0.735527                  0.783996

# %%
data_bg['Budget_Discrepancy'] = data_bg['Approved Labour Budget'] - data_bg['Total Exp(Rs. in Lakhs.)']
data_bg.head(10)
# Out:
#              state_name             district_name  Approved Labour Budget  \
# 0   ANDAMAN AND NICOBAR                  NICOBARS                0.040699
# 1   ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN                0.060849
# 2   ANDAMAN AND NICOBAR             SOUTH ANDAMAN                0.044145
# 5        ANDHRA PRADESH            VISAKHAPATANAM                0.261163
# 6        ANDHRA PRADESH             EAST GODAVARI                0.483579
# 7        ANDHRA PRADESH             WEST GODAVARI                0.406993
# 8        ANDHRA PRADESH                   KRISHNA                0.579791
# 9        ANDHRA PRADESH                    GUNTUR                0.375877
# 12       ANDHRA PRADESH                  CHITTOOR                0.583977
# 13       ANDHRA PRADESH                     Y.S.R                0.588134
#
#     Total Exp(Rs. in Lakhs.)  Budget_Discrepancy
# 0                   0.010387            0.030313
# 1                   0.057556            0.003293
# ...

# %%
data_bg.describe()
# Out:
#        Approved Labour Budget  Total Exp(Rs. in Lakhs.)  Budget_Discrepancy
# count              721.000000                721.000000          721.000000
# mean                 0.329075                  0.319861            0.009214
# std                  0.156080                  0.168892            0.069412
# min                  0.000000                  0.000000           -0.224320
# 25%                  0.220561                  0.192043           -0.036081
# 50%                  0.330079                  0.313342            0.013077
# 75%                  0.426058                  0.426048            0.052272
# max                  0.735527                  0.783996            0.259543

# %%
# Categorical Comparison - Example: Grouped bar chart for different regions
grouped_data = data_bg.groupby('state_name')[['Approved Labour Budget', 'Total Exp(Rs. in Lakhs.)']].mean()
grouped_data.plot(kind='bar', figsize=(10, 26))
plt.title('Budget vs. Actual Spending by State')
plt.xlabel('State')
plt.ylabel('Amount (in Lakhs)')
plt.show()

# %%
# Calculate the ratio of actual spending to budget for each state
grouped_data['Spending to Budget Ratio'] = grouped_data['Total Exp(Rs. in Lakhs.)'] / grouped_data['Approved Labour Budget']

# Define a threshold for significant variance (e.g., 1.2 indicating 20% overage)
threshold = 1.2

# Filter states where actual spending significantly exceeds the approved budget
significant_overage = grouped_data[grouped_data['Spending to Budget Ratio'] > threshold]
print("States with significant budget overage:")
print(significant_overage)
# Out:
# States with significant budget overage:
#              Approved Labour Budget  Total Exp(Rs. in Lakhs.)  \
# state_name
# PUDUCHERRY                 0.137133                  0.187785
# TAMIL NADU                 0.460139                  0.558478
# TELANGANA                  0.318320                  0.401182
# WEST BENGAL                0.000000                  0.066338
#
#              Spending to Budget Ratio
# state_name
# PUDUCHERRY                   1.369358
# TAMIL NADU                   1.213716
# TELANGANA                    1.260310
# WEST BENGAL                       inf

# %% [markdown]
# In the analysis, comparing the approved labor budget and the actual expenditure by state, a substantial disparity between the budget and the actual spending is notable for Puducherry by the allocated threshold. The actual expenditure significantly surpassed the approved budget, indicating a considerable overage in spending for this particular state compared to the allocated budget.

# %% [markdown]
# For geo files:
# https://drive.google.com/drive/folders/13lNjqqDUmC-jM_pFQy6Hb7z9WOcSUgXS

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns

# Sample data (Replace this with your dataset)

# Load the India map shapefile
india = gpd.read_file("/content/india_ds.shp")

# Merge state boundaries with the Budget Discrepancy data
merged = india.set_index('STATE').join(data_bg.set_index('state_name'))

# Plotting the choropleth map for Budget Discrepancy
fig, ax = plt.subplots(1, 1, figsize=(10, 8))
merged.plot(column='Budget_Discrepancy', cmap='YlGnBu', linewidth=0.8, ax=ax, vmin=-0.2,vmax=0.2,edgecolor='0.8', legend=True)
ax.axis('off')  # Turn off the axis
ax.set_title('Budget Discrepancy Across States')
plt.show()

# %% [markdown]
# ## DATA MODELLING

# %%
sns.pairplot(x_vars='Approved Labour Budget', y_vars='Total Exp(Rs. in Lakhs.)', data = data_bg)

# %%
#CREATE TESTING AND TRAINING DATASET
X=data[['Approved Labour Budget']]
y=data['Total Exp(Rs. in Lakhs.)']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.7,random_state=100)

# %%
#TRAIN THE MODEL
from sklearn.linear_model import LinearRegression
lr=LinearRegression(fit_intercept =True)
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('Linear Model Coefficient (m): ', lr.coef_)
print('Linear Model Coefficient (b): ', lr.intercept_)
# Out:
# Linear Model Coefficient (m):  [0.00259943]
# Linear Model Coefficient (b):  -256.6619879257796

# %%
#TEST THE MODEL
y_predict = lr.predict( X_test)
y_predict
# Out:
# array([ 7.99754057e+03,  7.82931562e+03,  3.35359752e+04,  3.09365416e+04,
#         3.87791916e+03,  7.12602066e+03,  1.14949124e+03,  2.14501453e+03,
#         5.64730684e+03,  3.90243182e+03,  1.19713415e+04,  1.28381149e+04,
#         5.73778793e+03,  5.20214863e+03, -2.56661988e+02,  6.15156858e+02,
#        -1.43116128e+02,  1.76786790e+03,  2.58209110e+03,  3.88518560e+04,
#         3.83026114e+03, -2.56376050e+02,  1.28368440e+03,  6.01086124e+02,
#         1.69878247e+04,  8.32146899e+03,  1.77157208e+04,  4.84441458e+03,
#         4.19619662e+02,  9.29841673e+03,  2.91314717e+03,  2.11738201e+04,
#         9.06360729e+03,  4.05340973e+02,  1.16665502e+04, -2.56661988e+02,
#         1.19748718e+03,  5.58872861e+03,  5.26477419e+03,  6.67343587e+03,
#         1.03148735e+03,  1.92810999e+03,  6.04454990e+02,  1.25543399e+04,
#         1.82288492e+03,  4.96274080e+03,  7.53488297e+03,  6.68428330e+03,
# ...

# %%
y_test
# Out:
# 569    12154.733910
# 327     3822.637151
# 277    32461.758620
# 19     37406.338750
# 423      870.546465
#            ...
# 328     4082.962644
# 211      212.849682
# 529    27142.522870
# 576    24936.962550
# 399     2880.453578
# Name: Total Exp(Rs. in Lakhs.), Length: 222, dtype: float64

# %%
#Evaluate Model
plt.scatter(X_train, y_train, color = 'black')
plt.plot(X_train, lr.predict(X_train), color = 'red')
plt.ylabel('Total Exp(Rs. in Lakhs.)')
plt.xlabel('Approved Labour Budget')
# Out:
# Text(0.5, 0, 'Approved Labour Budget')

# %%
#Calculate r2
from sklearn.metrics import r2_score
r2_score(y_test,y_predict)
# Out:
# 0.7982952367558074

# %%
data_bg.describe()
# Out:
#        Approved Labour Budget  Total Exp(Rs. in Lakhs.)  Budget_Discrepancy
# count              721.000000                721.000000          721.000000
# mean                 0.329075                  0.319861            0.009214
# std                  0.156080                  0.168892            0.069412
# min                  0.000000                  0.000000           -0.224320
# 25%                  0.220561                  0.192043           -0.036081
# 50%                  0.330079                  0.313342            0.013077
# 75%                  0.426058                  0.426048            0.052272
# max                  0.735527                  0.783996            0.259543

# %%
# Selecting features and target variable
features = data_bg[['Approved Labour Budget', 'Total Exp(Rs. in Lakhs.)']]  # Assuming these are the features
target = (data_bg['Total Exp(Rs. in Lakhs.)'] > data_bg['Approved Labour Budget']).astype(int)  # Binary classification

# %%
# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.7, random_state=42)

# %%
# Standardizing features
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Initialize and fit the logistic regression model
from sklearn.linear_model import LogisticRegression
lm = LogisticRegression()
lm.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Predicting on the test set
y_pred = lm.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
# Create a confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
# Display the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[310   3]
#  [ 25 167]]

# %%
# Plotting the confusion matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, cmap="Blues", fmt="d")
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
# Assuming you have the confusion matrix values
TP = 310  # True Positives
TN = 167  # True Negatives
FP = 25   # False Positives
FN = 3   # False Negatives

# Calculating metrics
accuracy = (TP + TN) / (TP + TN + FP + FN)
precision = TP / (TP + FP)
recall = TP / (TP + FN)
specificity = TN / (TN + FP)
f1_score = 2 * (precision * recall) / (precision + recall)

# Displaying the metrics
print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Sensitivity (Recall): {recall:.2f}")
print(f"Specificity: {specificity:.2f}")
print(f"F1 Score: {f1_score:.2f}")
# Out:
# Accuracy: 0.94
# Precision: 0.93
# Sensitivity (Recall): 0.99
# Specificity: 0.87
# F1 Score: 0.96

# %%
# Evaluate the model
accuracy = lm.score(X_test, y_test)
print("Accuracy of the logistic regression model:", accuracy)
# Out:
# Accuracy of the logistic regression model: 0.9445544554455445

# %%
#3.Persondays Analysis:

# %% [markdown]
# ## DATA PREPARATION

# %%
data_pd=data[['state_name','district_name','Persondays of Central Liability so far','SC persondays','ST persondays','Women Persondays']]
data_pd.head(10)
# Out:
#             state_name             district_name  \
# 0  ANDAMAN AND NICOBAR                  NICOBARS
# 1  ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN
# 2  ANDAMAN AND NICOBAR             SOUTH ANDAMAN
# 3       ANDHRA PRADESH                SRIKAKULAM
# 4       ANDHRA PRADESH              VIZIANAGARAM
# 5       ANDHRA PRADESH            VISAKHAPATANAM
# 6       ANDHRA PRADESH             EAST GODAVARI
# 7       ANDHRA PRADESH             WEST GODAVARI
# 8       ANDHRA PRADESH                   KRISHNA
# 9       ANDHRA PRADESH                    GUNTUR
#
#    Persondays of Central Liability so far  SC persondays  ST persondays  \
# 0                                    5046              0           4325
# 1                                   30487              0              0
# 2                                    4522              0              0
# 3                                15568613        1441624         999393
# ...

# %%
zero_counts = (data_pd == 0).sum()
zero_counts
# Out:
# state_name                                 0
# district_name                              0
# Persondays of Central Liability so far    11
# SC persondays                             62
# ST persondays                             50
# Women Persondays                          12
# dtype: int64

# %%
for i in data_pd.select_dtypes(include=['number']).columns:
  print(i)
  neg_counts = (data_pd[i] < 0).sum()
  print(neg_counts)
# Out:
# Persondays of Central Liability so far
# 0
# SC persondays
# 0
# ST persondays
# 0
# Women Persondays
# 0

# %%
for i in data_pd.select_dtypes(include=['number']).columns:
  sns.displot(data_pd[i])

# %%
data_pd.describe()
# Out:
#        Persondays of Central Liability so far  SC persondays  ST persondays  \
# count                            7.400000e+02   7.400000e+02   7.400000e+02
# mean                             2.233722e+06   4.340572e+05   3.783246e+05
# std                              2.564060e+06   6.333686e+05   9.388512e+05
# min                              0.000000e+00   0.000000e+00   0.000000e+00
# 25%                              4.891815e+05   2.893650e+04   5.239500e+03
# 50%                              1.511060e+06   2.027620e+05   7.276150e+04
# 75%                              2.839730e+06   5.250492e+05   4.297868e+05
# max                              1.588081e+07   3.974284e+06   1.234381e+07
#
#        Women Persondays
# count      7.400000e+02
# mean       1.322646e+06
# std        1.822721e+06
# min        0.000000e+00
# 25%        2.348888e+05
# 50%        7.188675e+05
# 75%        1.554468e+06
# max        1.312354e+07

# %%
for i in data_pd.select_dtypes(include=['number']).columns:
  median=data_pd[i].median()
  data_pd[i] = data_pd[i].replace(0,median)
# Out:
# <ipython-input-81-e32fc4b2556b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_pd[i] = data_pd[i].replace(0,median)
# <ipython-input-81-e32fc4b2556b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_pd[i] = data_pd[i].replace(0,median)
# <ipython-input-81-e32fc4b2556b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
for i in data_pd.select_dtypes(include=['number']).columns:
  data_pd[i]=data_pd[i].astype(int)
data_pd.head(10)
# Out:
# <ipython-input-82-756ba31cc9ee>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_pd[i]=data_pd[i].astype(int)
#             state_name             district_name  \
# 0  ANDAMAN AND NICOBAR                  NICOBARS
# 1  ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN
# 2  ANDAMAN AND NICOBAR             SOUTH ANDAMAN
# 3       ANDHRA PRADESH                SRIKAKULAM
# 4       ANDHRA PRADESH              VIZIANAGARAM
# 5       ANDHRA PRADESH            VISAKHAPATANAM
# 6       ANDHRA PRADESH             EAST GODAVARI
# 7       ANDHRA PRADESH             WEST GODAVARI
# 8       ANDHRA PRADESH                   KRISHNA
# 9       ANDHRA PRADESH                    GUNTUR
#
# ...

# %%
zero_counts = (data_pd == 0).sum()
zero_counts
# Out:
# state_name                                0
# district_name                             0
# Persondays of Central Liability so far    0
# SC persondays                             0
# ST persondays                             0
# Women Persondays                          0
# dtype: int64

# %%
for i in data_pd.select_dtypes(include=['number']).columns:
  sns.boxplot(x=data_pd[i])
  plt.show()

# %%
data_pd.loc[:, 'Persondays of Central Liability so far'] = np.sqrt(data_pd['Persondays of Central Liability so far'])
data_pd.loc[:, 'SC persondays'] = np.sqrt(data_pd['SC persondays'])
data_pd.loc[:, 'ST persondays'] = np.sqrt(data_pd['ST persondays'])
data_pd.loc[:, 'Women Persondays'] = np.sqrt(data_pd['Women Persondays'])
# Out:
# <ipython-input-85-97ead4b0adef>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_pd.loc[:, 'Persondays of Central Liability so far'] = np.sqrt(data_pd['Persondays of Central Liability so far'])
# <ipython-input-85-97ead4b0adef>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_pd.loc[:, 'SC persondays'] = np.sqrt(data_pd['SC persondays'])
# <ipython-input-85-97ead4b0adef>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
import pandas as pd

for i in data_pd.select_dtypes(include=['number']).columns:
# Assuming 'data_pd' is your DataFrame and 'column_name' is the specific column
  column = data_pd[i]

  Q1 = column.quantile(0.25)
  Q3 = column.quantile(0.75)
  IQR = Q3 - Q1

# Finding the number of outliers
# Define the boundaries for outliers
  lower_bound = Q1 - 1.5 * IQR
  upper_bound = Q3 + 1.5 * IQR

# Filter the DataFrame to exclude outliers in the specified column
  data_pd = data_pd[(column >= lower_bound) & (column <= upper_bound)]

# %%
for i in data_pd.select_dtypes(include=['number']).columns:
  sns.boxplot(x=data_pd[i])
  plt.show()

# %%
for i in data_pd.select_dtypes(include=['number']).columns:
  sns.displot(data_pd[i])
  plt.show()

# %% [markdown]
# ## DATA EXPLORATION

# %%
# Calculating the ratio of SC persondays, ST persondays, and Women persondays to Persondays of Central Liability
data_pd['SC Ratio'] = data_pd['SC persondays'] / data_pd['Persondays of Central Liability so far']
data_pd['ST Ratio'] = data_pd['ST persondays'] / data_pd['Persondays of Central Liability so far']
data_pd['Women Ratio'] = data_pd['Women Persondays'] / data_pd['Persondays of Central Liability so far']
data_pd.head(10)
# Out:
#              state_name             district_name  \
# 0   ANDAMAN AND NICOBAR                  NICOBARS
# 1   ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN
# 2   ANDAMAN AND NICOBAR             SOUTH ANDAMAN
# 5        ANDHRA PRADESH            VISAKHAPATANAM
# 6        ANDHRA PRADESH             EAST GODAVARI
# 7        ANDHRA PRADESH             WEST GODAVARI
# 9        ANDHRA PRADESH                    GUNTUR
# 13       ANDHRA PRADESH                     Y.S.R
# 15       ANDHRA PRADESH                   KURNOOL
# 23       ANDHRA PRADESH                   NANDYAL
#
#     Persondays of Central Liability so far  SC persondays  ST persondays  \
# 0                                71.035203     450.291017      65.764732
# 1                               174.605269     450.291017     269.742470
# 2                                67.245818     450.291017     269.742470
# 5                              1104.722137     312.776278      91.809586
# ...

# %%
category_persondays = data_pd[['SC persondays', 'ST persondays', 'Women Persondays']].sum()

# Visualization - Example: Pie chart for persondays contribution by categories
category_persondays.plot(kind='pie', autopct='%1.1f%%')
plt.title('Persondays Contribution by Categories')
plt.show()

# %%
threshold=3.5
# Assuming 'higher_sc_ratio' and 'higher_st_ratio' contain the filtered data_pd for SC and ST ratios higher than the threshold
higher_sc_ratio = data_pd[data_pd['SC Ratio'] > threshold]
higher_st_ratio = data_pd[data_pd['ST Ratio'] > threshold]

# Group by state and sum the higher SC and ST ratios
higher_sc_by_state = higher_sc_ratio.groupby('state_name')['SC Ratio'].sum()
higher_st_by_state = higher_st_ratio.groupby('state_name')['ST Ratio'].sum()

# Plotting state-wise bar graphs for SC and ST higher ratios
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
higher_sc_by_state.plot(kind='bar')
plt.title(f'State-wise SC Persondays Ratio >{threshold}')
plt.xlabel('State')
plt.ylabel('Total SC Ratio')

plt.subplot(1, 2, 2)
higher_st_by_state.plot(kind='bar', color='orange')
plt.title(f'State-wise ST Persondays Ratio >{threshold}')
plt.xlabel('State')
plt.ylabel('Total ST Ratio')



plt.tight_layout()
plt.show()

# %%
threshold=3.5
# Assuming 'higher_sc_ratio' and 'higher_st_ratio' contain the filtered data_pd for SC and ST ratios higher than the threshold
higher_women_ratio = data_pd[data_pd['Women Persondays'] > threshold]

# Group by state and sum the higher SC and ST ratios
higher_women_by_state = higher_st_ratio.groupby('state_name')['Women Persondays'].sum()

# Plotting state-wise bar graphs for SC and ST higher ratios
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 2)
higher_st_by_state.plot(kind='bar', color='red')
plt.title(f'State-wise Women Persondays Ratio >{threshold}')
plt.xlabel('State')
plt.ylabel('Total women Ratio')
# Out:
# Text(0, 0.5, 'Total women Ratio')

# %% [markdown]
# From the above bargraphs we can understand that West Bengal:
#
# 1.Stands out as the state exhibiting the highest total 'SC persondays' or 'ST persondays' ratios surpassing the defined threshold of 3.5.
#
# This observation suggests a dominant presence of social inclusion initiatives and robust policies promoting Scheduled Castes or Scheduled Tribes in employment opportunities within the region according to MNREGA.
#
# 2.It also exhibits highest total 'Women Persondays' ratios surpassing the defined threshold of 3.5.
#
# This observation suggests the promotion of gender inclusivity in labor-centric programs, potentially contributing to women's economic empowerment and reducing gender disparities.
#
# 3.Policies are effectively implemented for providing equitable employment opportunities

# %%
data_pd.head(5)
# Out:
#             state_name             district_name  \
# 0  ANDAMAN AND NICOBAR                  NICOBARS
# 1  ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN
# 2  ANDAMAN AND NICOBAR             SOUTH ANDAMAN
# 5       ANDHRA PRADESH            VISAKHAPATANAM
# 6       ANDHRA PRADESH             EAST GODAVARI
#
#    Persondays of Central Liability so far  SC persondays  ST persondays  \
# 0                               71.035203     450.291017      65.764732
# 1                              174.605269     450.291017     269.742470
# 2                               67.245818     450.291017     269.742470
# 5                             1104.722137     312.776278      91.809586
# 6                             1924.698678    1195.826074     268.853120
#
#    Women Persondays  SC Ratio  ST Ratio  Women Ratio
# 0         39.191836  6.338984  0.925805     0.551724
# 1        137.655367  2.578909  1.544870     0.788380
# 2         57.043843  6.696194  4.011290     0.848288
# ...

# %%
data.head(5)
# Out:
#    SNo.           state_name             district_name  \
# 0     1  ANDAMAN AND NICOBAR                  NICOBARS
# 1     2  ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN
# 2     3  ANDAMAN AND NICOBAR             SOUTH ANDAMAN
# 3     4       ANDHRA PRADESH                SRIKAKULAM
# 4     5       ANDHRA PRADESH              VIZIANAGARAM
#
#    Total No. of JobCards issued  Total No. of Workers  \
# 0                          6173                  9866
# 1                         18521                 29500
# 2                         13726                 17491
# 3                        445787                743762
# 4                        388651                694622
#
#    Total No. of Active Job Cards  Total No. of Active Workers  \
# 0                           1007                         2011
# 1                           6477                        11920
# 2                           3420                         5016
# ...

# %%
data_pd.head(5)
# Out:
#             state_name             district_name  \
# 0  ANDAMAN AND NICOBAR                  NICOBARS
# 1  ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN
# 2  ANDAMAN AND NICOBAR             SOUTH ANDAMAN
# 5       ANDHRA PRADESH            VISAKHAPATANAM
# 6       ANDHRA PRADESH             EAST GODAVARI
#
#    Persondays of Central Liability so far  SC persondays  ST persondays  \
# 0                               71.035203     450.291017      65.764732
# 1                              174.605269     450.291017     269.742470
# 2                               67.245818     450.291017     269.742470
# 5                             1104.722137     312.776278      91.809586
# 6                             1924.698678    1195.826074     268.853120
#
#    Women Persondays  SC Ratio  ST Ratio  Women Ratio
# 0         39.191836  6.338984  0.925805     0.551724
# 1        137.655367  2.578909  1.544870     0.788380
# 2         57.043843  6.696194  4.011290     0.848288
# ...

# %% [markdown]
# ### DATA MODELING

# %%
plt.figure(figsize=(8, 6))
corrlon=data_pd.corr()
heatmap = sns.heatmap(corrlon, annot=True, cmap="coolwarm", fmt=".3f")
plt.title('Correlation Heatmap')
plt.show()
# Out:
# <ipython-input-96-f3be520da3b2>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrlon=data_pd.corr()

# %%
# Selecting features and target variable
X = data_pd[['SC persondays', 'ST persondays', 'Women Persondays']]
y = data_pd['Persondays of Central Liability so far']

# Initializing and fitting the Multiple Linear Regression model
mlr_model = LinearRegression()
mlr_model.fit(X, y)

y_pred = mlr_model.predict(X)
# Making predictions on the features
data_pd['Predicted Persondays of Central Liability'] = y_pred

# Plotting the regression line and scatter plot for multiple states
plt.figure(figsize=(12, 8))

# Scatter plot with regression line for multiple states
sns.lmplot(x='Persondays of Central Liability so far', y='Predicted Persondays of Central Liability', data=data_pd, hue='state_name', ci=None, height=6, aspect=2, scatter_kws={"s": 50, "alpha": 0.6}, line_kws={"color": "red"})

plt.title('Actual vs. Predicted Persondays of Central Liability (MLR) by State')
plt.xlabel('Actual Persondays of Central Liability')
plt.ylabel('Predicted Persondays of Central Liability')

plt.show()

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
coefficients = lr.coef_
intercept = lr.intercept_
mae = mean_absolute_error(y, y_pred)
mse = mean_squared_error(y, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y, y_pred)
print(f"Coefficients: {coefficients}")
print(f"Intercept: {intercept}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"R-squared (R2): {r2}")
# Out:
# Coefficients: [0.00259943]
# Intercept: -256.6619879257796
# Mean Absolute Error (MAE): 114.60780993485359
# Mean Squared Error (MSE): 24171.55937690492
# Root Mean Squared Error (RMSE): 155.47205336299163
# R-squared (R2): 0.92997093725517

# %%
data.head(5)
# Out:
#    SNo.           state_name             district_name  \
# 0     1  ANDAMAN AND NICOBAR                  NICOBARS
# 1     2  ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN
# 2     3  ANDAMAN AND NICOBAR             SOUTH ANDAMAN
# 3     4       ANDHRA PRADESH                SRIKAKULAM
# 4     5       ANDHRA PRADESH              VIZIANAGARAM
#
#    Total No. of JobCards issued  Total No. of Workers  \
# 0                          6173                  9866
# 1                         18521                 29500
# 2                         13726                 17491
# 3                        445787                743762
# 4                        388651                694622
#
#    Total No. of Active Job Cards  Total No. of Active Workers  \
# 0                           1007                         2011
# 1                           6477                        11920
# 2                           3420                         5016
# ...

# %%
#Wage Rate Analysis

# %% [markdown]
# ## DATA PREPARATION

# %%
data_wg=data[['state_name','district_name','Total Exp(Rs. in Lakhs.)','Wages(Rs. In Lakhs)','Material and skilled Wages(Rs. In Lakhs)','Total Adm Expenditure (Rs. in Lakhs.)']]
data_wg.head(11)
# Out:
#              state_name             district_name  Total Exp(Rs. in Lakhs.)  \
# 0   ANDAMAN AND NICOBAR                  NICOBARS                  5.470080
# 1   ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN                167.966502
# 2   ANDAMAN AND NICOBAR             SOUTH ANDAMAN                 79.200820
# 3        ANDHRA PRADESH                SRIKAKULAM              50704.068270
# 4        ANDHRA PRADESH              VIZIANAGARAM              48338.747750
# 5        ANDHRA PRADESH            VISAKHAPATANAM               4033.530908
# 6        ANDHRA PRADESH             EAST GODAVARI              13340.339110
# 7        ANDHRA PRADESH             WEST GODAVARI              11250.730050
# 8        ANDHRA PRADESH                   KRISHNA              21586.415160
# 9        ANDHRA PRADESH                    GUNTUR               9102.121961
# 10       ANDHRA PRADESH                  PRAKASAM              44477.720110
#
# ...

# %%
data_wg.isna().sum()
# Out:
# state_name                                  0
# district_name                               0
# Total Exp(Rs. in Lakhs.)                    0
# Wages(Rs. In Lakhs)                         0
# Material and skilled Wages(Rs. In Lakhs)    0
# Total Adm Expenditure (Rs. in Lakhs.)       0
# dtype: int64

# %%
for i in data_wg.select_dtypes(include=['number']).columns:
  print(i)
  has_zeroes = (data_wg[i] == 0).any()
  print(has_zeroes)
# Out:
# Total Exp(Rs. in Lakhs.)
# True
# Wages(Rs. In Lakhs)
# True
# Material and skilled Wages(Rs. In Lakhs)
# True
# Total Adm Expenditure (Rs. in Lakhs.)
# True

# %%
for i in data_wg.select_dtypes(include=['number']).columns:
  median = data_wg[i].median()
  data_wg[i] = data_wg[i].replace(0, median)
# Out:
# <ipython-input-104-343234502f1d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_wg[i] = data_wg[i].replace(0, median)
# <ipython-input-104-343234502f1d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_wg[i] = data_wg[i].replace(0, median)
# <ipython-input-104-343234502f1d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
data_wg.head(10)
# Out:
#             state_name             district_name  Total Exp(Rs. in Lakhs.)  \
# 0  ANDAMAN AND NICOBAR                  NICOBARS                  5.470080
# 1  ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN                167.966502
# 2  ANDAMAN AND NICOBAR             SOUTH ANDAMAN                 79.200820
# 3       ANDHRA PRADESH                SRIKAKULAM              50704.068270
# 4       ANDHRA PRADESH              VIZIANAGARAM              48338.747750
# 5       ANDHRA PRADESH            VISAKHAPATANAM               4033.530908
# 6       ANDHRA PRADESH             EAST GODAVARI              13340.339110
# 7       ANDHRA PRADESH             WEST GODAVARI              11250.730050
# 8       ANDHRA PRADESH                   KRISHNA              21586.415160
# 9       ANDHRA PRADESH                    GUNTUR               9102.121961
#
#    Wages(Rs. In Lakhs)  Material and skilled Wages(Rs. In Lakhs)  \
# 0             5.470080                               1037.863258
# ...

# %%
for i in data_wg.select_dtypes(include=['number']).columns:
  print(i)
  has_zeroes = (data_wg[i] == 0).any()
  print(has_zeroes)
# Out:
# Total Exp(Rs. in Lakhs.)
# False
# Wages(Rs. In Lakhs)
# False
# Material and skilled Wages(Rs. In Lakhs)
# False
# Total Adm Expenditure (Rs. in Lakhs.)
# False

# %%
for i in data_wg.select_dtypes(include=['number']).columns:
  print(i)
  has_zeroes = (data_wg[i] < 0).any()
  print(has_zeroes)
# Out:
# Total Exp(Rs. in Lakhs.)
# False
# Wages(Rs. In Lakhs)
# False
# Material and skilled Wages(Rs. In Lakhs)
# False
# Total Adm Expenditure (Rs. in Lakhs.)
# False

# %%
for i in data_wg.select_dtypes(include=['number']).columns:
  sns.displot(data_wg[i])

# %%
for i in data_wg.select_dtypes(include=['number']).columns:
  sns.boxplot(x=data_wg[i])
  plt.show()

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Assuming 'df' is your DataFrame with the columns: 'Approved Labour Budget' and 'Total Exp(Rs. in Lakhs.)'

# Subset the columns containing integer features
integer_columns = ['Total Exp(Rs. in Lakhs.)','Wages(Rs. In Lakhs)','Material and skilled Wages(Rs. In Lakhs)','Total Adm Expenditure (Rs. in Lakhs.)']

# Initialize MinMaxScaler
scaler = MinMaxScaler()

# Normalize the integer columns using Min-Max scaling
data_wg[integer_columns] = scaler.fit_transform(data_wg[integer_columns])
# Out:
# <ipython-input-110-3d71ae13f321>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_wg[integer_columns] = scaler.fit_transform(data_wg[integer_columns])

# %%
data_wg.loc[:, 'Total Exp(Rs. in Lakhs.)'] = np.sqrt(data_wg['Total Exp(Rs. in Lakhs.)'])
data_wg.loc[:, 'Wages(Rs. In Lakhs)'] = np.sqrt(data_wg['Wages(Rs. In Lakhs)'])
data_wg.loc[:, 'Material and skilled Wages(Rs. In Lakhs)'] = np.sqrt(data_wg['Material and skilled Wages(Rs. In Lakhs)'])
data_wg.loc[:, 'Total Adm Expenditure (Rs. in Lakhs.)'] = np.sqrt(data_wg['Total Adm Expenditure (Rs. in Lakhs.)'])
# Out:
# <ipython-input-111-da2f1cd7033a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_wg.loc[:, 'Total Exp(Rs. in Lakhs.)'] = np.sqrt(data_wg['Total Exp(Rs. in Lakhs.)'])
# <ipython-input-111-da2f1cd7033a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_wg.loc[:, 'Wages(Rs. In Lakhs)'] = np.sqrt(data_wg['Wages(Rs. In Lakhs)'])
# <ipython-input-111-da2f1cd7033a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
import pandas as pd

for i in data_wg.select_dtypes(include=['number']).columns:
# Assuming 'data_wg' is your DataFrame and 'column_name' is the specific column
  column = data_wg[i]

  Q1 = column.quantile(0.25)
  Q3 = column.quantile(0.75)
  IQR = Q3 - Q1

# Finding the number of outliers
# Define the boundaries for outliers
  lower_bound = Q1 - 1.5 * IQR
  upper_bound = Q3 + 1.5 * IQR

# Filter the DataFrame to exclude outliers in the specified column
  data_wg = data_wg[(column >= lower_bound) & (column <= upper_bound)]

# %%
data_wg.fillna(0, inplace=True)

# %%
for i in data_wg.select_dtypes(include=['number']).columns:
  sns.displot(data_wg[i])

# %%
for i in data_wg.select_dtypes(include=['number']).columns:
  sns.boxplot(x=data_wg[i])
  plt.show()

# %% [markdown]
# ## DATA EXPLORATION

# %%
data_wg.head(11)
# Out:
#              state_name             district_name  Total Exp(Rs. in Lakhs.)  \
# 0   ANDAMAN AND NICOBAR                  NICOBARS                  0.010051
# 1   ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN                  0.057497
# 2   ANDAMAN AND NICOBAR             SOUTH ANDAMAN                  0.039436
# 5        ANDHRA PRADESH            VISAKHAPATANAM                  0.282036
# 6        ANDHRA PRADESH             EAST GODAVARI                  0.512930
# 7        ANDHRA PRADESH             WEST GODAVARI                  0.471046
# 9        ANDHRA PRADESH                    GUNTUR                  0.423685
# 18       ANDHRA PRADESH                 KONASEEMA                  0.583376
# 20       ANDHRA PRADESH                       NTR                  0.679106
# 21       ANDHRA PRADESH                   BAPATLA                  0.640793
# 22       ANDHRA PRADESH                   PALNADU                  0.695170
#
# ...

# %%
plt.figure(figsize=(8, 6))
corrlon=data_wg.corr()
heatmap = sns.heatmap(corrlon, annot=True, cmap="coolwarm", fmt=".3f")
plt.title('Correlation Heatmap')
plt.show()
# Out:
# <ipython-input-117-2aea0c45496a>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrlon=data_wg.corr()

# %%
# Calculate the percentage distribution of different expenditure types
data_wg['Wages Percentage'] = (data_wg['Wages(Rs. In Lakhs)'] / data_wg['Total Exp(Rs. in Lakhs.)']) * 100
data_wg['Material Skilled Wages Percentage'] = (data_wg['Material and skilled Wages(Rs. In Lakhs)'] / data_wg['Total Exp(Rs. in Lakhs.)']) * 100
data_wg['Admin Expenditure Percentage'] = (data_wg['Total Adm Expenditure (Rs. in Lakhs.)'] / data_wg['Total Exp(Rs. in Lakhs.)']) * 100

# %%
# Replace NaN values with 0 in the expenditure columns to prevent errors
#data_wg.fillna(0, inplace=True)

# Calculate the total expenditure for each category
total_wages = data_wg['Wages(Rs. In Lakhs)'].sum()
total_material_skilled = data_wg['Material and skilled Wages(Rs. In Lakhs)'].sum()
total_admin = data_wg['Total Adm Expenditure (Rs. in Lakhs.)'].sum()

# Calculate percentages
wages_percentage = (total_wages / (total_wages + total_material_skilled + total_admin)) * 100
material_skilled_percentage = (total_material_skilled / (total_wages + total_material_skilled + total_admin)) * 100
admin_percentage = (total_admin / (total_wages + total_material_skilled + total_admin)) * 100

# Prepare data for the pie chart
total_contributions = [wages_percentage, material_skilled_percentage, admin_percentage]
categories = ['Wages', 'Material and Skilled Wages', 'Admin Expenditure']

# Create a pie chart to display the combined contributions
plt.pie(total_contributions, labels=categories, autopct='%1.1f%%')
plt.title('Contribution of Expenditure Categories to Total Expenditure')
plt.show()

# %%
# Grouping data by state and summing SC and ST workers employed
exp = data_wg.groupby('state_name')[['Wages Percentage', 'Material Skilled Wages Percentage', 'Admin Expenditure Percentage']].mean()

# Plotting a stacked bar graph for SC and ST workers employed in different states
exp.plot(kind='bar', stacked=True, figsize=(12, 8))
plt.title('Expenditure Distribution by State')
plt.xlabel('States')
plt.ylabel('Percentage of Expenditure')
plt.xticks(rotation=90)
plt.show()



exp['Total Exp(Rs. in Lakhs.)'] = exp['Wages Percentage'] + exp['Material Skilled Wages Percentage'] + exp['Admin Expenditure Percentage']
top_5_states = exp.nlargest(5, 'Total Exp(Rs. in Lakhs.)')
print("Top 5 states with high expenditure")
print(top_5_states)
# Out:
# Top 5 states with high expenditure
#                      Wages Percentage  Material Skilled Wages Percentage  \
# state_name
# LAKSHADWEEP                 96.785012                          68.476651
# ANDAMAN AND NICOBAR        109.196343                         870.670658
# WEST BENGAL                153.200833                         392.780724
# HARYANA                    100.944418                         176.608621
# MANIPUR                     80.705336                         152.739041
#
#                      Admin Expenditure Percentage  Total Exp(Rs. in Lakhs.)
# state_name
# LAKSHADWEEP                           2464.250302               2629.511965
# ANDAMAN AND NICOBAR                   1072.490011               2052.357013
# WEST BENGAL                            532.936964               1078.918521
# HARYANA                                200.625981                478.179020
# MANIPUR                                154.407349                387.851726

# %% [markdown]
# In the above bar graph,West Bengal exhibited a notably higher wage percentage in the total expenditure compared to other states in the dataset. This indicates a relatively larger allocation of financial resources towards wages within employment schemes in West Bengal

# %%
bottom_5_states = exp.nsmallest(5, 'Total Exp(Rs. in Lakhs.)')
print("Bottom 5 states with high expenditure")
print(bottom_5_states)
# Out:
# Bottom 5 states with high expenditure
#             Wages Percentage  Material Skilled Wages Percentage  \
# state_name
# KERALA            105.707036                          46.170666
# PUDUCHERRY        107.839077                          20.026716
# RAJASTHAN         105.461783                          44.059484
# NAGALAND           94.340916                          86.729784
# GOA                83.054146                         113.343609
#
#             Admin Expenditure Percentage  Total Exp(Rs. in Lakhs.)
# state_name
# KERALA                         38.843065                190.720766
# PUDUCHERRY                     80.578136                208.443928
# RAJASTHAN                      65.777365                215.298631
# NAGALAND                       53.018640                234.089340
# GOA                            38.379161                234.776915

# %% [markdown]
# In the above bar graph,Goa exhibited a notably lower wage percentage in the total expenditure compared to other states in the dataset. This indicates a relatively smaller allocation of financial resources towards wages within employment schemes in Goa.

# %%
import geopandas as gpd

# Your existing code for identifying significant discrepancies
#significant_discrepancies = data_bg[data_bg['Budget_Discrepancy'].abs() > 0.156]
#grouped_data_bg = significant_discrepancies.groupby('state_name')['Budget_Discrepancy'].agg(['mean', 'max', 'min'])


india = gpd.read_file("/content/india_ds.shp")

# Merge the map with the grouped data
merged = india.merge(exp, how='left', left_on='STATE', right_index=True)

# Plotting the choropleth map with maximum 'Wages Percentage' values
fig, ax = plt.subplots(1, 1, figsize=(10, 8))
merged.plot(column='Wages Percentage', ax=ax, legend=True, cmap='YlGnBu', edgecolor='black')
plt.title('Maximum Wages Percentage by State')
plt.show()

# %%
specific_state = 'WEST BENGAL'
state_data = data_wg[data_wg['state_name'] == specific_state]
# Grouping data by state and summing SC and ST workers employed
exp1 = state_data.groupby('district_name')[['Wages Percentage', 'Material Skilled Wages Percentage', 'Admin Expenditure Percentage']].mean()

# Plotting a stacked bar graph for SC and ST workers employed in different states
exp1.plot(kind='bar', stacked=True, figsize=(12, 8))
plt.title('Expenditure Distribution of West Bengal')
plt.xlabel('States')
plt.ylabel('Percentage of Expenditure')
plt.xticks(rotation=90)
plt.show()



exp1['Total Exp(Rs. in Lakhs.)'] = exp1['Wages Percentage'] + exp1['Material Skilled Wages Percentage'] + exp1['Admin Expenditure Percentage']
top_5_states1 = exp1.nlargest(5, 'Total Exp(Rs. in Lakhs.)')
print("Top 5 districts with high expenditure")
print(top_5_states1)
# Out:
# Top 5 districts with high expenditure
#                            Wages Percentage  \
# district_name
# KALIMPONG                       1197.341339
# SILIGURI MAHAKUMA PARISAD        811.805442
# PURBA BARDHAMAN                   62.108967
# JALPAIGURI                       452.224138
# COOCHBEHAR                       380.954325
#
#                            Material Skilled Wages Percentage  \
# district_name
# KALIMPONG                                        1068.776755
# SILIGURI MAHAKUMA PARISAD                         724.637793
# PURBA BARDHAMAN                                  1346.455175
# JALPAIGURI                                        403.666550
# COOCHBEHAR                                        340.049336
#
#                            Admin Expenditure Percentage  \
# district_name
# KALIMPONG                                    618.625767
# SILIGURI MAHAKUMA PARISAD                    618.030429
# PURBA BARDHAMAN                              509.444888
# ...

# %% [markdown]
# In the above bar graph, Kalimpong district exhibited a significantly higher wage percentage in the total expenditure compared to other districts of West Bengal in the dataset. This indicates a relatively larger allocation of financial resources towards wages within employment schemes in Kalimpong district.

# %%
bottom_5_states1 = exp1.nsmallest(5, 'Total Exp(Rs. in Lakhs.)')
print("Bottom 5 districts with high expenditure")
print(bottom_5_states1)
# Out:
# Bottom 5 districts with high expenditure
#                                        Wages Percentage  \
# district_name
# ALIPURDUAR                                    91.062752
# Darjeeling Gorkha Hill Council (DGHC)         91.062752
# JHARGRAM                                      91.062752
# PASCHIM MEDINIPUR                             25.327344
# HOOGHLY                                        3.218970
#
#                                        Material Skilled Wages Percentage  \
# district_name
# ALIPURDUAR                                                     81.284885
# Darjeeling Gorkha Hill Council (DGHC)                          81.284885
# JHARGRAM                                                       81.284885
# PASCHIM MEDINIPUR                                             237.837820
# HOOGHLY                                                       253.638584
#
#                                        Admin Expenditure Percentage  \
# district_name
# ...

# %% [markdown]
# In the above bar graph,Hooghly exhibited a notably lower wage percentage in the total expenditure compared to other districts of West Bengal in the dataset. This indicates a relatively smaller allocation of financial resources towards wages within employment schemes in Hooghly.
